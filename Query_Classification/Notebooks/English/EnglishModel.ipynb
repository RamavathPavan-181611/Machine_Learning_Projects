# %%
"""English Voting Classifier"""

from google.colab import drive
import os
import pandas as pd
import re
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import string

from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from imblearn.under_sampling import RandomUnderSampler
import xgboost as xgb
from pickle import dump


nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()


drive.mount('/content/drive')


def clean_and_preprocess(text):
    text = str(text).lower()
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)  # Remove punctuation
    tokens = nltk.word_tokenize(text)
    tokens = [stemmer.stem(word) for word in tokens if word not in stop_words and word.isalpha()]
    return " ".join(tokens)


def load_data(csv_path):
    data = pd.read_csv(csv_path, encoding='utf-8')
    data['Query'] = data['Query'].apply(clean_and_preprocess)
    return data


def preprocess_data(data, label_column='Label', text_column='Query'):
    X = data[text_column]
    y = data[label_column]
    return X, y


def get_classifiers():
    return {
        'LR': LogisticRegression(),
        'RF': RandomForestClassifier(),
        'MNB': MultinomialNB(),
        'SVM': LinearSVC(),
        'SGD': SGDClassifier(),
        'XGB': xgb.XGBClassifier()
    }


def save_model(clf, model_name, vectorizer, fold_folder):
    os.makedirs(fold_folder, exist_ok=True)

    model_path = os.path.join(fold_folder, f'{model_name}_model.pkl')
    with open(model_path, 'wb') as model_file:
        dump(clf, model_file)

    vect_path = os.path.join(fold_folder, f'{model_name}_vectorizer.pkl')
    with open(vect_path, 'wb') as file:
        dump(vectorizer, file)

    print(f"Saved model and vectorizer to {fold_folder}")


def save_classification_report_and_confusion_matrix(y_true, y_pred, results_folder, model_name, class_names):
    os.makedirs(results_folder, exist_ok=True)

    report_path = os.path.join(results_folder, f'{model_name}_report.txt')
    with open(report_path, 'w') as file:
        file.write(classification_report(y_true, y_pred))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', linewidths=0.5,
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix: {model_name}')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.tight_layout()

    cm_path = os.path.join(results_folder, f'{model_name}_cm.png')
    plt.savefig(cm_path)
    plt.close()

def plot_class_distribution(y):
    plt.figure(figsize=(8,6))
    sns.countplot(x=y)
    plt.title('Class Distribution')
    plt.xlabel('Class Name')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/AI_Project/English/EDA/class_distribution.png')
    plt.close()


def train_and_save_voting_models(X, y, base_classifiers):

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

    combinations_3 = list(itertools.combinations(base_classifiers.items(), 3))
    combinations_5 = list(itertools.combinations(base_classifiers.items(), 5))

    final_results = []

    for combs, folder_prefix in [(combinations_3, '3m'), (combinations_5, '5m')]:
        for comb in combs:
            model_names = [name for name, _ in comb]
            models = [(name, clf) for name, clf in comb]
            model_name = "_".join(model_names)

            print(f"Training VotingClassifier: {model_name}")


            word_vect = TfidfVectorizer(analyzer='word', ngram_range=(1,1))
            char_vect = TfidfVectorizer(analyzer='char', ngram_range=(2,5))
            feature_union = FeatureUnion([
                ('word_tfidf', word_vect),
                ('char_tfidf', char_vect)
            ])

            X_train_tfidf = feature_union.fit_transform(X_train)
            X_test_tfidf = feature_union.transform(X_test)


            rus = RandomUnderSampler(random_state=42)
            X_res, y_res = rus.fit_resample(X_train_tfidf, y_train)


            voting_clf = VotingClassifier(estimators=models, voting='hard', n_jobs=-1)
            voting_clf.fit(X_res, y_res)
            y_pred = voting_clf.predict(X_test_tfidf)


            fold_folder = f"/content/drive/MyDrive/AI_Project/English/{folder_prefix}/{model_name}"
            results_folder = os.path.join(fold_folder, 'reports')
            save_model(voting_clf, model_name, feature_union, fold_folder)

            class_names = y.unique()
            save_classification_report_and_confusion_matrix(y_test, y_pred, results_folder, model_name, class_names)

            micro_f1 = precision_recall_fscore_support(y_test, y_pred, average='micro')[2]
            final_results.append({
                'Model': model_name,
                'Feature': 'word(1gram)+char(2-5gram)',
                'Micro F1': micro_f1
            })

    results_df = pd.DataFrame(final_results)
    results_df = results_df.sort_values(by='Micro F1', ascending=False)
    results_df.to_csv('/content/drive/MyDrive/AI_Project/English/voting_classifier_results.csv', index=False)
    print("Voting classifier results saved.")


def main():
    data_path = '/content/English_Query_Train.csv'
    data = load_data(data_path)

    X, y = preprocess_data(data)
    print("Class distribution:")
    print(y.value_counts())

    os.makedirs('/content/drive/MyDrive/AI_Project/English/EDA', exist_ok=True)
    plot_class_distribution(y)

    classifiers = get_classifiers()
    train_and_save_voting_models(X, y, classifiers)


if __name__ == '__main__':
    main()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Class distribution:
# Label
# Plant Protection                   18959
# Weather                            11614
# Nutrient Management                 4423
# Cultural Practices                  4210
# Fertilizer Use and Availability     2602
# Market Information                  2039
# Government Schemes                  2019
# Weed Management                     1503
# Varieties                           1350
# Field Preparation                   1280
# Name: count, dtype: int64
# Training VotingClassifier: LR_RF_MNB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_RF_MNB
# Training VotingClassifier: LR_RF_SVM
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_RF_SVM
# Training VotingClassifier: LR_RF_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_RF_SGD
# Training VotingClassifier: LR_RF_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_RF_XGB
# Training VotingClassifier: LR_MNB_SVM
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_MNB_SVM
# Training VotingClassifier: LR_MNB_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_MNB_SGD
# Training VotingClassifier: LR_MNB_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_MNB_XGB
# Training VotingClassifier: LR_SVM_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_SVM_SGD
# Training VotingClassifier: LR_SVM_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_SVM_XGB
# Training VotingClassifier: LR_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/LR_SGD_XGB
# Training VotingClassifier: RF_MNB_SVM
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_MNB_SVM
# Training VotingClassifier: RF_MNB_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_MNB_SGD
# Training VotingClassifier: RF_MNB_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_MNB_XGB
# Training VotingClassifier: RF_SVM_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_SVM_SGD
# Training VotingClassifier: RF_SVM_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_SVM_XGB
# Training VotingClassifier: RF_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/RF_SGD_XGB
# Training VotingClassifier: MNB_SVM_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/MNB_SVM_SGD
# Training VotingClassifier: MNB_SVM_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/MNB_SVM_XGB
# Training VotingClassifier: MNB_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/MNB_SGD_XGB
# Training VotingClassifier: SVM_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/3m/SVM_SGD_XGB
# Training VotingClassifier: LR_RF_MNB_SVM_SGD
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/LR_RF_MNB_SVM_SGD
# Training VotingClassifier: LR_RF_MNB_SVM_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/LR_RF_MNB_SVM_XGB
# Training VotingClassifier: LR_RF_MNB_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/LR_RF_MNB_SGD_XGB
# Training VotingClassifier: LR_RF_SVM_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/LR_RF_SVM_SGD_XGB
# Training VotingClassifier: LR_MNB_SVM_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/LR_MNB_SVM_SGD_XGB
# Training VotingClassifier: RF_MNB_SVM_SGD_XGB
# Saved model and vectorizer to /content/drive/MyDrive/AI_Project/English/5m/RF_MNB_SVM_SGD_XGB
# Voting classifier results saved.
